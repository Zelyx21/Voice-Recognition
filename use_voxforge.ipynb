# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results_df = pd.read_csv("voxforge_results.csv")

results_df["speaker"] = (
    results_df["speaker"]
    .str.lower()
    .str.replace("_", "", regex=False)
    .str.strip()
)

results_df["predicted"] = (
    results_df["predicted"]
    .str.lower()
    .str.replace("_", "", regex=False)
    .str.strip()
)

results_df = results_df[
    results_df["speaker"] != "anonymous"
]

results_df = results_df[
    results_df["predicted"] != "anonymous"
]


# Nettoyage
invalid_values = ["inconnu", "sélectionnez"]

columns_to_clean = [
    "speaker",
    "predicted",
    "dialect",
    "age",
    "gender"
]

results_df = results_df[
    ~results_df[columns_to_clean]
        .astype(str)
        .apply(lambda col: col.str.strip().str.lower())
        .isin(invalid_values)
        .any(axis=1)
]


# Fusion des pseudos équivalents
rename_map = {
    "rabea2008": "arbae",
    "cdricvasseuraliasbeepmaster": "cedricvasseuraliasbeepmaster",
    "franois": "francois",
    "jpquantin": "jpquanti"
}

results_df["speaker"] = results_df["speaker"].replace(rename_map)

results_df["predicted"] = results_df["predicted"].replace(rename_map)

results_df["correct"] = (
    results_df["speaker"] ==
    results_df["predicted"]
)

# %%
print(results_df.head())

print(results_df.info())

print(results_df.describe(include="all"))
# Out:
#   speaker predicted     score  correct    gender     age          dialect
# 0      4h        4h  0.753887     True  Masculin  Adulte  Français Suisse
# 1      4h        4h  0.773214     True  Masculin  Adulte  Français Suisse
# 2      4h        4h  0.731784     True  Masculin  Adulte  Français Suisse
# 3      4h        4h  0.645861     True  Masculin  Adulte  Français Suisse
# 4      4h        4h  0.715495     True  Masculin  Adulte  Français Suisse
# <class 'pandas.core.frame.DataFrame'>
# Index: 18436 entries, 0 to 23379
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   speaker    18436 non-null  object
#  1   predicted  18436 non-null  object
#  2   score      18436 non-null  float64
#  3   correct    18436 non-null  bool
#  4   gender     18436 non-null  object
#  5   age        18436 non-null  object
#  6   dialect    18436 non-null  object
# dtypes: bool(1), float64(1), object(5)
# memory usage: 1.0+ MB
# None
#         speaker predicted         score correct    gender     age  \
# count     18436     18436  18436.000000   18436     18436   18436
# unique      311       315           NaN       2         2       3
# top     fao10rk   fao10rk           NaN    True  Masculin  Adulte
# freq       2156      2085           NaN   16518     17649   15023
# mean        NaN       NaN      0.652541     NaN       NaN     NaN
# std         NaN       NaN      0.089737     NaN       NaN     NaN
# min         NaN       NaN      0.273814     NaN       NaN     NaN
# 25%         NaN       NaN      0.588123     NaN       NaN     NaN
# 50%         NaN       NaN      0.661511     NaN       NaN     NaN
# 75%         NaN       NaN      0.719360     NaN       NaN     NaN
# max         NaN       NaN      0.999910     NaN       NaN     NaN
#
#                 dialect
# count             18436
# unique                6
# top     Français France
# freq              16361
# mean                NaN
# std                 NaN
# min                 NaN
# 25%                 NaN
# 50%                 NaN
# 75%                 NaN
# max                 NaN

# %%
accuracy = results_df["correct"].mean()

print(f"Accuracy globale : {accuracy:.4f}")
# Out:
# Accuracy globale : 0.8960

# %%
results_df["score"].hist(bins=50)

plt.title("Distribution des scores")
plt.xlabel("Score")
plt.ylabel("Count")
plt.show()

# %%
results_df[results_df["correct"]]["score"].hist(
    bins=50,
    alpha=0.5,
    label="Correct"
)

results_df[~results_df["correct"]]["score"].hist(
    bins=50,
    alpha=0.5,
    label="Incorrect"
)

plt.legend()
plt.title("Scores corrects vs incorrects")
plt.show()

# %%
gender_stats = (
    results_df
    .groupby("gender")["correct"]
    .agg(["mean", "count"])
    .rename(columns={"mean": "accuracy"})
)

print(gender_stats)
# Out:
#           accuracy  count
# gender
# Féminin   0.941550    787
# Masculin  0.893932  17649

# %%
dialect_stats = (
    results_df
    .groupby("dialect")["correct"]
    .agg(["mean", "count"])
    .sort_values("mean")
)

print(dialect_stats)
# Out:
#                         mean  count
# dialect
# Français d'Afrique  0.222222      9
# Français France     0.890105  16361
# Français Belgique   0.922360   1288
# Français Québécois  0.981308    321
# Autre               0.981818    110
# Français Suisse     0.985591    347

# %%
age_stats = (
    results_df
    .assign(correct_int=results_df["correct"].astype(int))
    .groupby("age")["correct_int"]
    .agg(
        accuracy="mean",
        count="count"
    )
    .sort_values("accuracy")
)

print(age_stats)
# Out:
#         accuracy  count
# age
# Adulte  0.890501  15023
# Jeune   0.911542   3041
# Senior  0.989247    372

# %%
speaker_stats = (
    results_df
    .groupby("speaker")["correct"]
    .agg(["mean", "count"])
    .rename(columns={"mean": "accuracy"})
)

print("Plus faciles")
print(speaker_stats.sort_values("accuracy", ascending=False).head(10))

print("Plus difficiles")
print(speaker_stats.sort_values("accuracy").head(10))
# Out:
# Plus faciles
#           accuracy  count
# speaker
# zg             1.0      9
# 4h             1.0      9
# abuisine       1.0     19
# yreveill       1.0      9
# alain          1.0     19
# vinch          1.0    139
# vince          1.0      9
# vilrax         1.0    109
# upacesky       1.0     39
# tth            1.0      9
# Plus difficiles
#              accuracy  count
# speaker
# lucas        0.101695     59
# dth0         0.222222      9
# ramzi        0.230769     39
# thierry      0.240506     79
# ben          0.241379     29
# wwwdarnoxfr  0.315789     19
# paco         0.342105     38
# gsx          0.368421     19
# benot        0.444444      9
# ckiw         0.473684     19

# %%
confusions = (
    results_df[~results_df["correct"]]
    .groupby(["speaker", "predicted"])
    .size()
    .reset_index(name="count")
    .sort_values("count", ascending=False)
)

print(confusions.head(20))
# Out:
#                speaker                     predicted  count
# 15               arbae  cedricvasseuraliasbeepmaster    153
# 168  jeanmarccortiella              gonzalezjeanmarc     69
# 130            fao10rk                           tof     61
# 366            thierry                      thierryb     50
# 350       samuelbuffet                      nanochan     48
# 51               arbae                          yawn     43
# 351       samuelbuffet                          nclm     43
# 201             lorand                       d3m0t3p     38
# 173         jobesancon               libertairebesac     35
# 347       samuelbuffet                       kolyawe     34
# 47               arbae                        trimss     31
# 293          philippea                          nclm     28
# 356       samuelbuffet                         rowin     26
# 42               arbae                      seb02859     26
# 22               arbae                         frank     25
# 13               arbae                       candide     24
# 420               tuux                      jfornech     23
# 363           thevenin                       thvenin     22
# 150   gonzalezjeanmarc             jeanmarccortiella     22
# 7                arbae                       anonyme     20

# %%
cm = confusion_matrix(
    results_df["speaker"],
    results_df["predicted"],
    labels=labels,
    normalize="true"
)

plt.figure(figsize=(15,15))

sns.heatmap(
    cm,
    cmap="magma"
)

plt.title("Normalized confusion matrix")
plt.xlabel("Predicted")
plt.ylabel("True")

plt.show()

# %%
#qui est confondu avec qui ?

cm = confusion_matrix(
    results_df["speaker"],
    results_df["predicted"],
    labels=labels,
    normalize="true"
)

cm_df = pd.DataFrame(
    cm,
    index=labels,
    columns=labels
)

# enlève la diagonale
np.fill_diagonal(cm_df.values, 0)

top_confusions = (
    cm_df.stack()
    .sort_values(ascending=False)
    .head(20)
)

print(top_confusions)
# Out:
# colinecarreremsncom  colinecarrere          0.444444
# ckiw                 clochette              0.400000
# colinecarrere        colinecarreremsncom    0.265306
# ramzi                panazol                0.250000
# philippea            nclm                   0.201439
# bailly39             arbae                  0.186441
# dada                 dude                   0.157895
# frank                laarmen                0.135135
# eric                 yreveill               0.125000
#                      kolyawe                0.125000
# elucify              test                   0.125000
# samuelbuffet         nanochan               0.115942
# loic                 test                   0.111111
# rousset              bruno                  0.111111
# ff561                laarmen                0.111111
# jfornech             dude                   0.111111
# jerome07             jerome                 0.111111
# samuelbuffet         nclm                   0.103865
# ramzi                koubiak                0.093750
# samuelbuffet         kolyawe                0.082126
# dtype: float64

# %%
results_df.groupby("correct")["score"].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# correct
# False     1918.0  0.544337  0.077763  0.273814  0.491162  0.530047  0.581216
# True     16518.0  0.665105  0.082272  0.353186  0.609640  0.671308  0.725046
#
#               max
# correct
# False    0.812083
# True     0.999910

# %%
thresholds = np.arange(0, 1.01, 0.01)

stats = []

for t in thresholds:
    subset = results_df[results_df["score"] >= t]

    if len(subset) == 0:
        continue

    acc = subset["correct"].mean()

    stats.append({
        "threshold": t,
        "accuracy": acc,
        "coverage": len(subset) / len(results_df)
    })

threshold_df = pd.DataFrame(stats)

# %%
plt.plot(threshold_df["threshold"], threshold_df["accuracy"])
plt.title("Accuracy selon threshold")
plt.xlabel("Threshold")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.plot(threshold_df["threshold"], threshold_df["coverage"])
plt.title("Coverage selon threshold")
plt.xlabel("Threshold")
plt.ylabel("Coverage")
plt.show()

# %%
bias_stats = (
    results_df
    .groupby(["gender", "dialect"])["correct"]
    .mean()
    .unstack()
)

print(bias_stats)
# Out:
# dialect      Autre  Français Belgique  Français France  Français Québécois  \
# gender
# Féminin   1.000000                NaN         0.933526            1.000000
# Masculin  0.972603            0.92236         0.888187            0.977186
#
# dialect   Français Suisse  Français d'Afrique
# gender
# Féminin               NaN                 NaN
# Masculin         0.985591            0.222222

# %%
plt.scatter(results_df["age"], results_df["score"])

plt.xlabel("Age")
plt.ylabel("Score")
plt.title("Score vs Age")
plt.show()

# %%
numeric_df = results_df.select_dtypes(include="number")

print(numeric_df.corr())
# Out:
#        score
# score    1.0

# %%
from sklearn.metrics import classification_report

print(classification_report(
    results_df["speaker"],
    results_df["predicted"]
))
# Out:
#                               precision    recall  f1-score   support
#
#                           4h       0.90      1.00      0.95         9
#                     abuisine       0.95      1.00      0.97        19
#                     agoniste       0.80      0.96      0.87        89
#                        alain       0.95      1.00      0.97        19
#                         alex       1.00      0.95      0.97        19
#                      alliage       1.00      0.90      0.95        69
#                  ambreserres       1.00      1.00      1.00        29
#                 angelamalice       0.75      1.00      0.86         9
#                         ango       1.00      1.00      1.00        19
#                        anod1       1.00      1.00      1.00        19
#                      anonyme       0.20      1.00      0.34         9
#                      anthony       1.00      1.00      1.00       309
#                       apb794       0.56      1.00      0.72         9
#                        arbae       0.97      0.59      0.74      1158
#                     artrobin       1.00      0.90      0.95        29
#                      arverne       0.93      1.00      0.96        79
#                     avescera       0.90      1.00      0.95         9
#                           ax       0.99      1.00      1.00       129
#                        aznur       0.99      0.95      0.97       209
#                     bailly39       1.00      0.81      0.90        59
#                         balt       0.57      0.89      0.70         9
#                       batman       0.82      1.00      0.90         9
#                      belleil       0.64      1.00      0.78         9
#                          ben       0.47      0.24      0.32        29
#                      benbull       0.47      1.00      0.64         8
#            benjaminverhaeghe       0.82      1.00      0.90         9
#                       benjar       0.68      0.97      0.80        29
#                        benob       1.00      0.97      0.99        69
#                        benot       0.50      0.44      0.47         9
#                        bigus       0.90      1.00      0.95         9
#                        bob44       1.00      0.97      0.98        29
#                 bricepedrono       0.43      1.00      0.60         9
#                        bruno       0.75      1.00      0.86         9
#                        bryan       0.82      1.00      0.90         9
#                      candide       0.39      0.95      0.55        19
#                     cedricmm       0.97      0.93      0.95       119
# cedricvasseuraliasbeepmaster       0.21      1.00      0.34        47
#                       choco7       0.97      0.77      0.86       119
#                        chris       1.00      1.00      1.00        49
#                 christophako       1.00      1.00      1.00         9
#                   christophe       0.61      1.00      0.76        19
#                christophedlr       1.00      1.00      1.00        19
#                         ckiw       0.75      0.47      0.58        19
#                     clavette       0.96      0.83      0.89        29
#                        clic4       1.00      0.99      0.99        69
#                    clochette       0.82      0.93      0.87        29
#                  clothildemm       1.00      1.00      1.00         9
#                         coco       0.98      0.97      0.97        99
#                colinecarrere       0.90      0.73      0.81        49
#          colinecarreremsncom       0.28      0.56      0.37         9
#                       costas       0.97      0.97      0.97        39
#                   courforest       0.69      1.00      0.82         9
#                          cpt       0.88      1.00      0.94        29
#                      d3m0t3p       0.16      1.00      0.27         9
#                         dada       0.94      0.84      0.89        19
#                    dantheman       1.00      1.00      1.00         9
#                      daxbrin       1.00      0.99      0.99        79
#                       decent       0.90      1.00      0.95         9
#                   deltabravo       1.00      1.00      1.00       149
#                        df4ze       0.94      1.00      0.97        29
#                         dgt1       1.00      1.00      1.00         9
#                         dima       0.90      1.00      0.95         9
#                        djouf       0.69      1.00      0.82         9
#                         dmon       0.67      0.95      0.78        19
#                    dominique       0.53      1.00      0.69         9
#                     drubayfp       0.97      0.99      0.98       279
#                         dth0       0.50      0.22      0.31         9
#                         dth1       0.53      0.89      0.67         9
#                         dude       0.45      1.00      0.62         9
#                     dudumomo       1.00      1.00      1.00        29
#                      edrin17       0.86      1.00      0.93        19
#                       edwynn       0.98      0.93      0.96        59
#                       elou44       0.99      1.00      0.99        79
#                         eloy       1.00      1.00      1.00         9
#                      elpanda       0.90      1.00      0.95        19
#                      elucify       1.00      0.78      0.88         9
#                         eric       1.00      0.67      0.80         9
#                      erics34       1.00      0.67      0.80         9
#                  ericvincent       0.85      1.00      0.92        29
#                    erreur404       0.92      1.00      0.96       169
#                       eruald       1.00      0.97      0.98        59
#                    etcaetera       0.84      1.00      0.92        49
#                      fabrice       1.00      1.00      1.00        19
#                      fao10rk       1.00      0.96      0.98      2156
#                       fatflo       0.90      1.00      0.95        19
#                      felynne       0.90      1.00      0.95        19
#                        ff561       1.00      0.89      0.94         9
#                        finch       0.96      0.99      0.97       109
#                        floif       0.41      0.78      0.54         9
#                     fmortgat       0.99      0.99      0.99       149
#                         frag       0.95      1.00      0.97        19
#                       franck       0.26      1.00      0.42         9
#                     francois       0.70      1.00      0.82        48
#                  francserres       1.00      0.92      0.96       319
#                        frank       0.49      0.74      0.59        39
#                  frankynight       0.86      1.00      0.93        19
#                       fredfr       0.86      1.00      0.93        19
#                         gael       0.98      0.99      0.99       199
#                    gardois80       0.75      1.00      0.86        18
#                       garous       0.93      0.83      0.88        99
#                   gemssydney       0.82      1.00      0.90         9
#                         gene       1.00      1.00      1.00        39
#                        geo79       1.00      1.00      1.00       239
#                       girdin       1.00      1.00      1.00         9
#                        godin       1.00      1.00      1.00         9
#             gonzalezjeanmarc       0.28      0.55      0.37        49
#                         greg       1.00      1.00      1.00         9
#                        gremy       0.75      1.00      0.86         9
#                     groutier       0.73      1.00      0.84        19
#                       grumpf       1.00      1.00      1.00       371
#                      gryphus       0.00      0.00      0.00         0
#                          gsx       0.88      0.37      0.52        19
#                          hlx       0.82      1.00      0.90         9
#                     hortense       1.00      1.00      1.00         9
#                hubertgendron       0.95      1.00      0.97        19
#                       iriamu       1.00      1.00      1.00         9
#          jacqueshoschtettler       1.00      0.91      0.95       109
#                       jarnot       0.35      1.00      0.51         9
#                       jasper       0.97      0.94      0.96       109
#                          jbl       1.00      1.00      1.00         9
#                      jeanbon       0.99      1.00      0.99        69
#                  jeancharles       0.82      1.00      0.90         9
#            jeanmarccortiella       0.82      0.62      0.70       189
#             jeanmarountorbey       1.00      1.00      1.00         9
#                   jeanrenard       0.95      1.00      0.97        19
#                       jerome       0.50      1.00      0.67        28
#                     jerome07       0.89      0.89      0.89         9
#                     jfornech       0.25      0.89      0.39         9
#                          jim       1.00      1.00      1.00         9
#                           jn       1.00      1.00      1.00         9
#                     jnbianco       0.95      1.00      0.97        19
#                           jo       1.00      0.67      0.80         9
#                   jobesancon       0.68      0.49      0.57        69
#                   jonathanmm       1.00      1.00      1.00         9
#                       jouflu       1.00      1.00      1.00        19
#                     jpetazzo       1.00      1.00      1.00         9
#                     jpquanti       0.99      1.00      1.00       348
#                  jr38francis       0.95      1.00      0.97        19
#                        jt580       0.31      1.00      0.47         9
#                      jtrampq       1.00      1.00      1.00        69
#                       julien       0.67      0.67      0.67         9
#              julienflajollet       1.00      0.78      0.88         9
#                    kadhaleen       0.69      1.00      0.82         9
#                        kanor       0.56      0.56      0.56         9
#                       karibu       0.95      1.00      0.97        19
#                      kawashi       1.00      1.00      1.00         9
#                     khalahan       0.69      1.00      0.82         9
#                          kiw       0.90      1.00      0.95        19
#                      kolyawe       0.19      1.00      0.32         9
#                      koubiak       0.69      1.00      0.82         9
#                      laarmen       0.93      0.96      0.95       119
#                      laurent       0.69      1.00      0.82        29
#                          lcf       0.73      1.00      0.84        19
#              lebourgphilippe       0.78      0.62      0.69        29
#             lebourgphilippe4       0.37      0.78      0.50         9
#                        lezmy       1.00      1.00      1.00        29
#              libertairebesac       0.40      0.59      0.47        39
#                       ljoets       0.46      0.67      0.55         9
#                          loc       0.32      1.00      0.49         9
#                       locked       0.97      0.84      0.90        69
#                         loic       0.89      0.89      0.89         9
#                       loic66       1.00      1.00      1.00         9
#                       lorand       1.00      0.88      0.94       719
#                 lorkscorguar       1.00      0.63      0.77        19
#                          luc       0.82      1.00      0.90         9
#                        lucas       0.29      0.10      0.15        59
#                    lucylinda       1.00      1.00      1.00         9
#                     luxurien       0.97      1.00      0.98        29
#                          mad       1.00      1.00      1.00         9
#                      maftieu       0.94      1.00      0.97        29
#                  magicbenoit       1.00      1.00      1.00         9
#                   magicienap       0.97      1.00      0.99        39
#                manonmcguigan       0.90      1.00      0.95         9
#                    manusashi       0.97      0.82      0.89        38
#                       marc42       0.95      1.00      0.97        19
#                      mariane       0.99      0.99      0.99       279
#               matthewwiesner       0.00      0.00      0.00         0
#                   maximedu14       0.82      1.00      0.90         9
#                        maxpi       1.00      1.00      1.00         9
#                 mgreg4msncom       1.00      1.00      1.00         9
#                   mgrenier25       1.00      0.84      0.91        19
#                        mguex       0.82      1.00      0.90         9
#                     mirage59       0.97      1.00      0.99        39
#                           mo       1.00      1.00      1.00        19
#                         mojo       0.92      0.99      0.96       109
#                          mwt       0.97      1.00      0.98        29
#                     nanochan       0.14      1.00      0.25         9
#                     nastymax       1.00      1.00      1.00        19
#                      nathann       0.96      0.98      0.97        49
#                        nbara       1.00      1.00      1.00        59
#                         nclm       0.34      0.80      0.48        49
#                     nekonemo       0.95      1.00      0.97        19
#                       neolao       1.00      0.97      0.98        29
#                   nerkdesign       0.97      1.00      0.99        38
#                    nesmontou       0.70      1.00      0.83        38
#                         ness       1.00      1.00      1.00        29
#                     ngombert       0.62      1.00      0.76        29
#                         nico       0.53      1.00      0.69         9
#                      nicolas       1.00      1.00      1.00        39
#             nicolasbernaerts       0.97      1.00      0.98        59
#                        nigao       1.00      1.00      1.00        39
#                   nikolasdys       1.00      0.95      0.97        19
#                       norsav       1.00      1.00      1.00         9
#                      noxygen       1.00      0.95      0.97        39
#                          noz       1.00      1.00      1.00        59
#                    oeildefeu       0.94      1.00      0.97        29
#                         olge       0.00      0.00      0.00         0
#                      olivier       0.95      0.95      0.95        19
#                      ordilem       0.90      1.00      0.95        19
#                       orgelf       0.95      1.00      0.97        19
#                       owedon       1.00      1.00      1.00        19
#                      oxydenz       0.95      1.00      0.97        39
#                         paco       1.00      0.34      0.51        38
#                   panameboss       0.90      1.00      0.95         9
#                      panazol       0.83      1.00      0.90        38
#                    pancrator       1.00      1.00      1.00         9
#                     patricia       0.82      1.00      0.90         9
#                       pauldb       1.00      1.00      1.00         9
#                  pengouinpdt       0.74      0.98      0.84        49
#                     phaielip       0.95      0.95      0.95        19
#                       philbe       1.00      0.92      0.96       819
#                     philippe       0.25      0.63      0.36        19
#                    philippea       1.00      0.59      0.74       159
#                    philippel       0.68      0.98      0.81        59
#                    philippen       0.60      0.64      0.62        39
#                       philou       0.64      1.00      0.78         9
#                        phils       0.97      1.00      0.99        38
#                  pierot13ans       1.00      1.00      1.00         9
#                       pols12       1.00      1.00      1.00       129
#                     ppaluplp       0.90      1.00      0.95         9
#                          psc       0.99      0.98      0.99       139
#                  pszacherski       0.95      1.00      0.97        19
#                       radium       1.00      1.00      1.00         9
#                        ramzi       0.90      0.23      0.37        39
#                      redguff       1.00      0.98      0.99       596
#                  reminoushka       1.00      0.96      0.98        49
#                       remmmi       1.00      1.00      1.00        19
#                       renaud       1.00      0.95      0.97        19
#                          rmy       0.82      1.00      0.90         9
#                    robotzeus       0.92      1.00      0.96        49
#                       romain       0.00      0.00      0.00         0
#                       ronono       0.31      1.00      0.47         9
#                      rousset       0.89      0.89      0.89         9
#                        rowin       0.15      0.56      0.23         9
#                    ryukahles       1.00      0.96      0.98        99
#                     saez0pub       1.00      0.98      0.99        49
#                 samuelbuffet       0.99      0.54      0.70       462
#                     sandoval       0.99      1.00      1.00       149
#                       satine       1.00      1.00      1.00         9
#                       schreu       0.64      1.00      0.78         9
#                          seb       1.00      1.00      1.00        29
#                     seb02859       0.33      0.84      0.48        19
#                    sebastien       0.82      1.00      0.90         9
#                    serial326       0.95      1.00      0.97        19
#                     severine       1.00      1.00      1.00         9
#               simonlavalette       1.00      1.00      1.00        19
#                       sissou       1.00      1.00      1.00        89
#                       skuydi       0.96      1.00      0.98        49
#                        sky99       0.90      1.00      0.95         9
#                        smile       0.80      0.97      0.88        29
#                          smk       1.00      1.00      1.00         9
#                   soldierftl       1.00      1.00      1.00         9
#                       sorkas       0.95      1.00      0.97        38
#                       speedy       1.00      1.00      1.00         9
#                         stem       1.00      1.00      1.00         9
#                stphanedamico       1.00      0.89      0.94         9
#                      suzanne       1.00      1.00      1.00         9
#                      sylafrs       0.50      1.00      0.67         9
#                      telliam       1.00      1.00      1.00        29
#                         test       0.47      1.00      0.64         9
#                     thevenin       0.98      0.65      0.78        62
#                      thierry       0.83      0.24      0.37        79
#                     thierryb       0.15      1.00      0.26         9
#                thinkrosystem       0.99      0.86      0.92       491
#            thinkrosystemanne       1.00      1.00      1.00        17
#                       thomas       1.00      1.00      1.00         9
#                      thosoum       0.38      0.84      0.52        19
#                      thvenin       0.27      0.89      0.41         9
#                        tiago       0.90      1.00      0.95         9
#                     tifanieb       0.90      1.00      0.95        19
#                          tla       0.82      1.00      0.90         9
#                          tof       0.24      1.00      0.38        19
#                         tomw       0.95      1.00      0.97        19
#                      tonkoya       1.00      1.00      1.00         9
#                        tonus       1.00      0.78      0.88         9
#                         tony       0.93      1.00      0.97        69
#                       topota       0.99      0.85      0.91        99
#                    toutjuste       1.00      1.00      1.00         9
#                       trimss       0.20      1.00      0.34         9
#                      troumad       0.82      1.00      0.90         9
#                          tth       0.90      1.00      0.95         9
#                         tuux       1.00      0.70      0.83       279
#                       tweepy       0.99      0.99      0.99       119
#                     upacesky       0.83      1.00      0.91        39
#                       vilrax       0.96      1.00      0.98       109
#                        vince       1.00      1.00      1.00         9
#                        vinch       0.99      1.00      0.99       139
#                      vincnet       0.60      0.95      0.73        19
#                    vroniqued       1.00      1.00      1.00        19
#                           vv       1.00      1.00      1.00        19
#                     wallifax       1.00      1.00      1.00        79
#                     wargadou       1.00      1.00      1.00        29
#                      whereis       1.00      1.00      1.00        19
#                      will421       0.90      1.00      0.95         9
#                 winniemiel05       1.00      1.00      1.00         9
#                         wuus       1.00      1.00      1.00        19
#                  wwwdarnoxfr       0.50      0.32      0.39        19
#                       xav973       0.90      1.00      0.95         9
#                       xavier       1.00      1.00      1.00         9
#                         xime       0.91      0.94      0.93        99
#                   yankeepapa       0.75      1.00      0.86         9
#                         yawn       0.20      0.63      0.30        19
#                  yeouepinard       0.99      1.00      0.99        89
#                     yreveill       0.60      1.00      0.75         9
#                           zg       0.69      1.00      0.82         9
#
#                     accuracy                           0.90     18436
#                    macro avg       0.83      0.92      0.85     18436
#                 weighted avg       0.94      0.90      0.91     18436
# d:\Projet\Voice-Recognition\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Projet\Voice-Recognition\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Projet\Voice-Recognition\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
hard_errors = results_df[
    (~results_df["correct"]) &
    (results_df["score"] > 0.8)
]

print(hard_errors.sort_values("score", ascending=False).head(20))
# Out:
#       speaker predicted     score  correct    gender     age  \
# 11968  garous  agoniste  0.812083    False  Masculin  Adulte
#
#                  dialect
# 11968  Français Belgique

# %%
pivot = (
    results_df
    .assign(correct_int=results_df["correct"].astype(int))
    .groupby(["age", "gender"])["correct_int"]
    .mean()
    .unstack()
)

sns.heatmap(pivot, annot=True)

plt.title("Accuracy Age x Gender")
plt.show()

# %%
for dialect in results_df["dialect"].unique():

    subset = results_df[results_df["dialect"] == dialect]

    subset["score"].hist(alpha=0.5, bins=30)

    plt.title(dialect)
    plt.show()

# %%
low_confidence_correct = results_df[
    (results_df["correct"]) &
    (results_df["score"] < 0.3)
]

high_confidence_wrong = results_df[
    (~results_df["correct"]) &
    (results_df["score"] > 0.8)
]

# %%
print(low_confidence_correct[
    ["speaker", "predicted", "dialect", "score"]
].head(20))
# Out:
# Empty DataFrame
# Columns: [speaker, predicted, dialect, score]
# Index: []

# %%
print(high_confidence_wrong[
    ["speaker", "predicted", "dialect", "score"]
].head(20))
# Out:
#       speaker predicted            dialect     score
# 11968  garous  agoniste  Français Belgique  0.812083

# %%
confusions = (
    high_confidence_wrong
    .groupby(["speaker", "predicted"])
    .size()
    .sort_values(ascending=False)
)

print(confusions.head(20))
# Out:
# speaker  predicted
# garous   agoniste     1
# dtype: int64

# %%
print(
    high_confidence_wrong["age"]
    .value_counts(normalize=True)
)
# Out:
# age
# Adulte    1.0
# Name: proportion, dtype: float64

# %%
print(
    high_confidence_wrong["gender"]
    .value_counts(normalize=True)
)
# Out:
# gender
# Masculin    1.0
# Name: proportion, dtype: float64

# %%
sns.histplot(results_df["score"], bins=50)

plt.title("Distribution des scores")
plt.show()

# %%
speaker_stats = (
    results_df
    .groupby("speaker")["correct"]
    .agg(
        accuracy="mean",
        samples="count"
    )
)

print(
    speaker_stats.sort_values("accuracy").head(20)
)
# Out:
#                      accuracy  samples
# speaker
# lucas                0.101695       59
# dth0                 0.222222        9
# ramzi                0.230769       39
# thierry              0.240506       79
# ben                  0.241379       29
# wwwdarnoxfr          0.315789       19
# paco                 0.342105       38
# gsx                  0.368421       19
# benot                0.444444        9
# ckiw                 0.473684       19
# jobesancon           0.492754       69
# samuelbuffet         0.536797      462
# gonzalezjeanmarc     0.551020       49
# colinecarreremsncom  0.555556        9
# kanor                0.555556        9
# rowin                0.555556        9
# libertairebesac      0.589744       39
# philippea            0.591195      159
# arbae                0.594128     1158
# jeanmarccortiella    0.619048      189
